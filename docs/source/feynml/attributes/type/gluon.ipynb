# %% [markdown]
# # gluon

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("gluon")
# Out:
# Pyx:
# <wand.image.Image: d8a74c2 'PDF' (157x22)>
# Tikz:
# <wand.image.Image: a416b55 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: 0a10637 'PDF' (180x111)>
# Dot:
# <wand.image.Image: f3698a1 'PDF' (476x73)>
# ASCIIPDF:
# <wand.image.Image: bf3f665 'PDF' (42x33)>
# MPL:
