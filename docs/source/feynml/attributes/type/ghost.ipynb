# %% [markdown]
# # ghost

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("ghost")
# Out:
# Tikz:
# <wand.image.Image: ae72cd8 'PDF' (88x88)>
# Feynmp:
# <wand.image.Image: e72b56b 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 2c3ca49 'PDF' (276x90)>
# ASCIIPDF:
# <wand.image.Image: 89e1d49 'PDF' (25x17)>
# MPL:
