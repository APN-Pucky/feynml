# %% [markdown]
# # boson

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("boson")
# Out:
# Pyx:
# <wand.image.Image: d26c689 'PDF' (157x30)>
# Tikz:
# <wand.image.Image: 7bee6cd 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: f683b4f 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 87a4c63 'PDF' (476x73)>
# ASCIIPDF:
# <wand.image.Image: 21d3bb4 'PDF' (42x33)>
# MPL:
# [0.]
# [0.]
