# %% [markdown]
# # higgs

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("higgs")
# Out:
# Pyx:
# <wand.image.Image: 569f17e 'PDF' (157x14)>
# Tikz:
# <wand.image.Image: aa2405e 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: ada5fe7 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 780c553 'PDF' (476x73)>
# ASCIIPDF:
# <wand.image.Image: 69f19ae 'PDF' (42x33)>
# MPL:
