# %% [markdown]
# # squark

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("squark")
# Out:
# Pyx:
# Pyx failed: 'squark'
# Tikz:
# <wand.image.Image: 7fa45dd 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: 9c9ee77 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 780c553 'PDF' (476x73)>
# ASCIIPDF:
# <wand.image.Image: 3a297e6 'PDF' (108x33)>
# MPL:
# MPL failed: 'squark'
