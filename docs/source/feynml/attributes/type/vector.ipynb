# %% [markdown]
# # vector

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("vector")
# Out:
# Pyx:
# <wand.image.Image: d26c689 'PDF' (157x30)>
# Tikz:
# <wand.image.Image: 7bee6cd 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: f683b4f 'PDF' (180x111)>
# Dot:
# Dot failed: 'vector'
# ASCIIPDF:
# ASCIIPDF failed: 'vector'
# MPL:
# MPL failed: 'vector'
